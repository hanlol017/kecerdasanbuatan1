# %%
import pandas as pd
dataset = "/content/DataSet.csv"

df = pd.read_csv(dataset)

df.head(10)
# Out:
#    Usia  Jenis Kelamin Jenis Nyeri Dada  Tekanan Darah  Kolesterol  \
# 0     63             M              ASY          140.0         187
# 1     63             F              ASY          124.0         197
# 2     41             M              ATA            NaN         157
# 3     59             M              ASY          164.0         176
# 4     57             F              ASY          140.0         241
# 5     45             M               TA          110.0         264
# 6     68             M              ASY            NaN         193
# 7     57             M              ASY          130.0         131
# 8     57             F              ATA          130.0         236
# 9     38             M              NAP            NaN         175
#
#    Gula Darah Puasa EKG Istirahat  Denyut Jantung Angina Latihan  Depresi ST  \
# 0                 0           LVH             144              Y         4.0
# ...

# %%
print(df['Tekanan Darah'].isna().sum())

df['Tekanan Darah'].fillna('N', inplace=True)

print(df['Tekanan Darah'].isna().sum())
# Out:
# 3
# 0

# %%
df['Angina Latihan'].replace(['10'], ['N'], inplace=True)

print(df['Angina Latihan'].value_counts())
# Out:
# N    6
# Y    4
# Name: Angina Latihan, dtype: int64
